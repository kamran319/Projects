# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#used for importing the images 
import cv2

# %%
#Pillow short from PIL ,used for importing the images
import PIL

# %%
# to check PIP version
import pip
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 5.1.0

# %%
print('Pillow Version:')
# Out:
# Pillow Version:

# %%
from PIL import Image

# %%
#Image.open is used for opening the image file in jupyter 1st method
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')

# %%
image.format
# Out:
# 'JPEG'

# %%
image.size
# Out:
# (640, 360)

# %%
image.mode
# Out:
# 'RGB'

# %%
image.show()

# %%
 from matplotlib import image

# %%
from matplotlib import pyplot

# %%
#to display & load the image 2nd method
data=image.imread('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')

# %%
data
# Out:
# array([[[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        [[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        [[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        ...,
#
#        [[ 85,  95, 104],
#         [ 75,  85,  94],
#         [ 81,  91, 100],
#         ...,
#         [ 64,  79, 100],
#         [ 60,  75,  96],
#         [ 62,  77,  98]],
#
#        [[ 72,  82,  91],
#         [ 60,  70,  79],
#         [ 51,  61,  70],
#         ...,
#         [ 61,  76,  97],
#         [ 58,  73,  94],
#         [ 53,  68,  91]],
#
#        [[ 31,  41,  51],
#         [ 33,  43,  53],
#         [ 29,  39,  49],
# ...

# %%
data.dtype
# Out:
# dtype('uint8')

# %%
data.shape
# Out:
# (360, 640, 3)

# %%
pyplot.imshow(data)

# %%
pyplot.show()

# %%
from PIL import Image

# %%
# to convert into array
from numpy import asarray

# %%
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x1B01EAD8E48>

# %%
data=asarray(image)

# %%
data
# Out:
# array([[[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        [[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        [[170, 187, 203],
#         [170, 187, 203],
#         [170, 187, 203],
#         ...,
#         [141, 165, 193],
#         [141, 165, 193],
#         [141, 165, 193]],
#
#        ...,
#
#        [[ 85,  95, 104],
#         [ 75,  85,  94],
#         [ 81,  91, 100],
#         ...,
#         [ 64,  79, 100],
#         [ 60,  75,  96],
#         [ 62,  77,  98]],
#
#        [[ 72,  82,  91],
#         [ 60,  70,  79],
#         [ 51,  61,  70],
#         ...,
#         [ 61,  76,  97],
#         [ 58,  73,  94],
#         [ 53,  68,  91]],
#
#        [[ 31,  41,  51],
#         [ 33,  43,  53],
#         [ 29,  39,  49],
# ...

# %%
data.shape
# Out:
# (360, 640, 3)

# %%
# create the pillow image
image2=Image.fromarray(data)

# %%
image2
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x1B01EAFA6A0>

# %%
image2.format

# %%
image2.mode
# Out:
# 'RGB'

# %%
image2.size
# Out:
# (640, 360)

# %%
image2.show()

# %%
image2.format

# %%
# load all the images in the directory
from os import listdir
from matplotlib import image

# %%
#load all the images in the directory
#loaded_images=list()
#for filename in litdir('images'):
    #load images
#    img_data=image.imread('images/'+ file name)
    #store the loaded image
#    loaded_images.append(img_data)
#    print('>loaded %s %s' % (filename,img_data.shape))

# %%
# example of saving an image in another format
from PIL import Image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
# save to PNG format
image.save('C:\\Users\\Ash\\Downloads\\Opera_House.png', format='PNG')
#load the image again & check the format
image2=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.png')

# %%
image2.format
# Out:
# 'PNG'

# %%
# example of saving an image in greyscale format
from PIL import Image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
# convert to greyscale format
gs_image=image.convert(mode='L')
#save in jpge format
gs_image.save('C:\\Users\\Ash\\Downloads\\Opera_House_grayscale.jpg')
#load the image again & check the format
image2=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House_grayscale.jpg')

# %%
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=640x360 at 0x1B01EB0A3C8>

# %%
#resizing the image,thumbnail function can be used fro that,reducing the size
from PIL import Image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
print(image.size)
image.thumbnail((100,100))
print(image.size)
# Out:
# (640, 360)
# (100, 56)

# %%
#resize the pixel into new shape
from PIL import Image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
print(image.size)
img_resized=image.resize((200,200))
print(img_resized.size)
# Out:
# (640, 360)
# (200, 200)

# %%
img_resized.show()

# %%
from PIL import Image
from matplotlib import pyplot
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
#horizontal flip, transpose function can b used
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
#vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
pyplot.subplot(311)
pyplot.imshow(image)
pyplot.subplot(312)
pyplot.imshow(hoz_flip)
pyplot.subplot(313)
pyplot.imshow(ver_flip)
pyplot.show()

# %%
from PIL import Image
from matplotlib import pyplot
# load image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
# plot original image
pyplot.subplot(311)
pyplot.imshow(image)
# rotate 45 degrees
pyplot.subplot(312)
pyplot.imshow(image.rotate(45))
# rotate 90 degrees
pyplot.subplot(313)
pyplot.imshow(image.rotate(90))
pyplot.show()

# %%
# example of cropping an image
from PIL import Image
# load image
image=Image.open('C:\\Users\\Ash\\Downloads\\Opera_House.jpg')
# create a cropped image
cropped = image.crop((100, 100, 200, 200))
# show cropped image
cropped.show()

# %%
#pip install tensor flow
#pip instal tflearn
#pip instal tqdm
#import numpy as no
#import os
#import cv2
#import
